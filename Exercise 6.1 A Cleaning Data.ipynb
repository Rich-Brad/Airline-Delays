# %% [markdown]
# # .01 Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # .02 Importing data

# %%
df_air_dlay = pd.read_csv(r'D:\Rich\Bus Analyst\1-2-2024 Airline Delays\02 Data\Original Data\airline_delay_data.csv',index_col=False)

# %%
# Path string

# %%
path = r'D:\Rich\Bus Analyst\1-2-2024 Airline Delays'

# %%
path
# Out:
# 'D:\\Rich\\Bus Analyst\\1-2-2024 Airline Delays'

# %%
# Basic checks
# df_air_dlay.head(20)
# df_air_dlay.tail(35)
# df_air_dlay.columns
# df_air_dlay.shape
# df_air_dlay.info()
# df_air_dlay.describe()

df_air_dlay.head(20)
# Out:
#     year  month carrier       carrier_name airport  \
# 0   2020     12      9E  Endeavor Air Inc.     ABE
# 1   2020     12      9E  Endeavor Air Inc.     ABY
# 2   2020     12      9E  Endeavor Air Inc.     AEX
# 3   2020     12      9E  Endeavor Air Inc.     AGS
# 4   2020     12      9E  Endeavor Air Inc.     ALB
# 5   2020     12      9E  Endeavor Air Inc.     ATL
# 6   2020     12      9E  Endeavor Air Inc.     ATW
# 7   2020     12      9E  Endeavor Air Inc.     AVL
# 8   2020     12      9E  Endeavor Air Inc.     AZO
# 9   2020     12      9E  Endeavor Air Inc.     BDL
# 10  2020     12      9E  Endeavor Air Inc.     BHM
# 11  2020     12      9E  Endeavor Air Inc.     BIS
# 12  2020     12      9E  Endeavor Air Inc.     BMI
# 13  2020     12      9E  Endeavor Air Inc.     BNA
# 14  2020     12      9E  Endeavor Air Inc.     BOS
# 15  2020     12      9E  Endeavor Air Inc.     BQK
# 16  2020     12      9E  Endeavor Air Inc.     BTR
# ...

# %%
df_air_dlay.tail(35)
# Out:
#       year  month carrier             carrier_name airport  \
# 3308  2019     12      DL     Delta Air Lines Inc.     ROA
# 3309  2019     12      DL     Delta Air Lines Inc.     ROC
# 3310  2019     12      DL     Delta Air Lines Inc.     RSW
# 3311  2019     12      DL     Delta Air Lines Inc.     SAN
# 3312  2019     12      DL     Delta Air Lines Inc.     SAT
# 3313  2019     12      DL     Delta Air Lines Inc.     SAV
# 3314  2019     12      DL     Delta Air Lines Inc.     SDF
# 3315  2019     12      DL     Delta Air Lines Inc.     SEA
# 3316  2019     12      DL     Delta Air Lines Inc.     SFO
# 3317  2019     12      DL     Delta Air Lines Inc.     SJC
# 3318  2019     12      DL     Delta Air Lines Inc.     SJU
# 3319  2019     12      DL     Delta Air Lines Inc.     SLC
# 3320  2019     12      DL     Delta Air Lines Inc.     SMF
# 3321  2019     12      DL     Delta Air Lines Inc.     SNA
# 3322  2019     12      DL     Delta Air Lines Inc.     SRQ
# ...

# %%
df_air_dlay.columns
# Out:
# Index(['year', 'month', 'carrier', 'carrier_name', 'airport',
#        'airport_location', 'city', 'state_abbr', 'airport_name', 'arr_flights',
#        'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct', 'security_ct',
#        'late_aircraft_ct', 'arr_cancelled', 'arr_diverted', 'arr_delay',
#        'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay',
#        'late_aircraft_delay'],
#       dtype='object')

# %%
df_air_dlay.shape
# Out:
# (3343, 24)

# %%
df_air_dlay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3343 entries, 0 to 3342
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 3343 non-null   int64
#  1   month                3343 non-null   int64
#  2   carrier              3343 non-null   object
#  3   carrier_name         3343 non-null   object
#  4   airport              3343 non-null   object
#  5   airport_location     3343 non-null   object
#  6   city                 3343 non-null   object
#  7   state_abbr           3343 non-null   object
#  8   airport_name         3343 non-null   object
#  9   arr_flights          3343 non-null   int64
#  10  arr_del15            3343 non-null   int64
#  11  carrier_ct           3343 non-null   float64
#  12  weather_ct           3343 non-null   float64
#  13  nas_ct               3343 non-null   float64
#  14  security_ct          3343 non-null   float64
# ...

# %%
df_air_dlay.describe()
# Out:
#               year   month   arr_flights    arr_del15   carrier_ct  \
# count  3343.000000  3343.0   3343.000000  3343.000000  3343.000000
# mean   2019.458271    12.0    298.271014    50.995214    16.065337
# std       0.498330     0.0    852.436335   146.484456    41.759516
# min    2019.000000    12.0      1.000000     0.000000     0.000000
# 25%    2019.000000    12.0     35.000000     5.000000     1.490000
# 50%    2019.000000    12.0     83.000000    12.000000     4.750000
# 75%    2020.000000    12.0    194.500000    33.000000    12.255000
# max    2020.000000    12.0  19713.000000  2289.000000   697.000000
#
#         weather_ct       nas_ct  security_ct  late_aircraft_ct  arr_cancelled  \
# count  3343.000000  3343.000000  3343.000000       3343.000000    3343.000000
# mean      1.443144    16.183383     0.137320         17.166069       2.884535
# std       4.821657    56.423008     0.646479         55.447043      10.126658
# ...

# %%
df_air_dlay.dtypes
# Out:
# year                     int64
# month                    int64
# carrier                 object
# carrier_name            object
# airport                 object
# airport_location        object
# city                    object
# state_abbr              object
# airport_name            object
# arr_flights              int64
# arr_del15                int64
# carrier_ct             float64
# weather_ct             float64
# nas_ct                 float64
# security_ct            float64
# late_aircraft_ct       float64
# arr_cancelled            int64
# arr_diverted             int64
# arr_delay                int64
# carrier_delay            int64
# weather_delay            int64
# nas_delay                int64
# security_delay           int64
# late_aircraft_delay      int64
# dtype: object

# %%
# Check columns with missing data

df_air_dlay.isnull().sum()
# Out:
# year                   0
# month                  0
# carrier                0
# carrier_name           0
# airport                0
# airport_location       0
# city                   0
# state_abbr             0
# airport_name           0
# arr_flights            0
# arr_del15              0
# carrier_ct             0
# weather_ct             0
# nas_ct                 0
# security_ct            0
# late_aircraft_ct       0
# arr_cancelled          0
# arr_diverted           0
# arr_delay              0
# carrier_delay          0
# weather_delay          0
# nas_delay              0
# security_delay         0
# late_aircraft_delay    0
# dtype: int64

# %% [markdown]
# # No missing data in columns

# %% [markdown]
# # Renaming columns for better description

# %%
# Rename arr_flight into number_arriving_flights
# df_air_dlay.rename(columns = {'arr_flights' : 'number_arriving_flights'}, inplace = True)

# Rename arr_del15 into number_flights_delay_greater_than_15min
# df_air_dlay.rename(columns = {'arr_flights' : 'number_flights_delay_greater_than_15min'}, inplace = True)

# Rename carrier_ct into number_flights_delay_no_crew
# df_air_dlay.rename(columns = {'carrier_ct' : 'number_flights_delay_no_crew'}, inplace = True)

# Rename weather_ct into number_flights_weather_delay
# df_air_dlay.rename(columns = {'weather_ct' : 'number_flights_weather_delay'}, inplace = True)

# Rename nas_ct into number_flights_heavy_air_traffic_delay
# df_air_dlay.rename(columns = {'nas_ct' : 'number_flights_heavy_air_traffic_delay'}, inplace = True)

# Rename security_ct into number_flights_security_breach_delay
# df_air_dlay.rename(columns = {'security_ct' : 'number_flights_security_breach_delay'}, inplace = True)

# Rename late_aircraft_ct into number_flights_for_same_aircraft_delay
# df_air_dlay.rename(columns = {'late_aircraft_ct' : 'number_flights_for_same_aircraft_delay'}, inplace = True)

# Rename arr_cancelled into number_cancelled_flights
# df_air_dlay.rename(columns = {'arr_cancelled' : 'number_cancelled_flights'}, inplace = True)

# Rename arr_diverted into number_flights_diverted
# df_air_dlay.rename(columns = {'arr_diverted' : 'number_flights_diverted'}, inplace = True)

# Rename arr_delay into flights_delay_total_minutes
# df_air_dlay.rename(columns = {'arr_delay' : 'flights_delay_total_minutes'}, inplace = True)

# Rename carrier_delay into carrier_delay_total_minutes
# df_air_dlay.rename(columns = {'carrier_delay' : 'carrier_delay_total_minutes'}, inplace = True)

# Rename weather_day into weather_delay_total_minutes
# df_air_dlay.rename(columns = {'weather_delay' : 'weather_delay_total_minutes'}, inplace = True)

# Rename nas_delay into air_traffic_delay_total_minutes
# df_air_dlay.rename(columns = {'nas_delay': 'air_traffic_delay_total_minutes'}, inplace = True)

# Rename security_delay into security_delay_total_minutes
# df_air_dlay.rename(columns = {'security_delay' : 'security_delay_total_minutes'}, inplace = True)

# Rename late_aircraft_delay into same_aircraft_delay_total_minutes
# df_air_dlay.rename(columns = {'late_aircraft_delay' : 'same_aircraft_delay_total_minutes'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'arr_flights' : 'number_arriving_flights'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'arr_del15' : 'number_flights_delay_greater_than_15min'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'carrier_ct' : 'number_flights_delay_no_crew'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'weather_ct' : 'number_flights_weather_delay'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'nas_ct' : 'number_flights_heavy_air_traffic_delay'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'security_ct' : 'number_flights_security_breach_delay'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'late_aircraft_ct' : 'number_flights_for_same_aircraft_delay'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'arr_cancelled' : 'number_cancelled_flights'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'arr_diverted' : 'number_flights_diverted'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'arr_delay' : 'flights_delay_total_minutes'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'carrier_delay' : 'carrier_delay_total_minutes'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'weather_delay' : 'weather_delay_total_minutes'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'nas_delay': 'air_traffic_delay_total_minutes'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'security_delay' : 'security_delay_total_minutes'}, inplace = True)

# %%
df_air_dlay.rename(columns = {'late_aircraft_delay' : 'same_aircraft_delay_total_minutes'}, inplace = True)

# %%
# check column names
# df_air_dlay.info()

df_air_dlay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3343 entries, 0 to 3342
# Data columns (total 24 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   year                                     3343 non-null   int64
#  1   month                                    3343 non-null   int64
#  2   carrier                                  3343 non-null   object
#  3   carrier_name                             3343 non-null   object
#  4   airport                                  3343 non-null   object
#  5   airport_location                         3343 non-null   object
#  6   city                                     3343 non-null   object
#  7   state_abbr                               3343 non-null   object
#  8   airport_name                             3343 non-null   object
#  9   number_arriving_flights                  3343 non-null   int64
# ...

# %%
# check shape
# df_air_dlay.shape

df_air_dlay.shape
# Out:
# (3343, 24)

# %%
# check columns
# df_air_dlay.columns

df_air_dlay.columns
# Out:
# Index(['year', 'month', 'carrier', 'carrier_name', 'airport',
#        'airport_location', 'city', 'state_abbr', 'airport_name',
#        'number_arriving_flights', 'number_flights_delay_greater_than_15min',
#        'number_flights_delay_no_crew', 'number_flights_weather_delay',
#        'number_flights_heavy_air_traffic_delay',
#        'number_flights_security_breach_delay',
#        'number_flights_for_same_aircraft_delay', 'number_cancelled_flights',
#        'number_flights_diverted', 'flights_delay_total_minutes',
#        'carrier_delay_total_minutes', 'weather_delay_total_minutes',
#        'air_traffic_delay_total_minutes', 'security_delay_total_minutes',
#        'same_aircraft_delay_total_minutes'],
#       dtype='object')

# %% [markdown]
# # Export df_air_dlay data as 'df_air_dlay_clean.csv' in Prepared Data

# %%
df_air_dlay.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_air_dlay_clean.csv'))
